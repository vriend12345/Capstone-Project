# %% [markdown]
# # Capstone Project

# %% [markdown]
# # Finding best locations for an advertisement campaign in Istanbul, Turkey

# %% [markdown]
# ## The Description of the Problem
# **ABC Limited** is a touristic company in Istanbul, Turkey. It wants to start an advertisement campaign for its touristic tours targeting the tourists in Istanbul traveling without a previously arranged tour programs.
#
# Its budget can cover the advertisements in only limited areas.  We want to use the spatial data for Istanbul City and analyze it in order to infer the most populated neighborhoods by tourists, that contain tourists who are willing to pay for the tours.

# %% [markdown]
# ## The Description of the Data and how it will be used to solve the problem
# We will use the data from “Inside Airbnb site” which is sourced from publicly available information from the “Airbnb site”.
# http://insideairbnb.com/get-the-data.html
#
# We can find the detailed listings data for Istanbul in “Inside Airbnb site” from the link:
# http://data.insideairbnb.com/turkey/marmara/istanbul/2018-11-21/data/listings.csv.gz
#
# Using Airbnb listing data rather hotels listing data has an advantage that most of the hotels’ clients are coming to Istanbul in groups with pre-arranged tour programs, where as the clients of Airbnb are usually arranging their own travels, accommodations, tour programs.
# We want to choose the five most prominent zipcodes of the most populated neighborhood by tourists, based on the distributions of the Airbnb properties and the per-night prices of them.

# %% [markdown]
# ### Importing the required libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 

# !pip install folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Requirement already satisfied: folium in c:\users\hazim\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: branca>=0.3.0 in c:\users\hazim\anaconda3\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied: numpy in c:\users\hazim\anaconda3\lib\site-packages (from folium) (1.15.4)
# Requirement already satisfied: six in c:\users\hazim\anaconda3\lib\site-packages (from folium) (1.12.0)
# Requirement already satisfied: requests in c:\users\hazim\anaconda3\lib\site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2 in c:\users\hazim\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\hazim\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\hazim\anaconda3\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\hazim\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hazim\anaconda3\lib\site-packages (from requests->folium) (2018.11.29)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hazim\anaconda3\lib\site-packages (from jinja2->folium) (1.1.0)
# Libraries imported.

# %% [markdown]
# ### Importing the data

# %%
df = pd.read_csv('http://data.insideairbnb.com/turkey/marmara/istanbul/2018-11-21/data/listings.csv.gz', compression='gzip', 
                 index_col=0, low_memory=False)

# %% [markdown]
# ### Exploring the data

# %%
df.shape
# Out:
# (14927, 95)

# %%
df.columns
# Out:
# Index(['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url',
#        'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ### Subseting the relevant columns

# %%
df1 = df[['name', 'neighbourhood', 'zipcode', 'latitude', 'longitude', 'accommodates', 'price']]

# %%
df1.head()
# Out:
#                                       name neighbourhood zipcode   latitude  \
# id
# 4826                             The Place       Üsküdar   34684  41.056499
# 20815    The Bosphorus from The Comfy Hill      Beşiktaş   34345  41.069842
# 25436  House for vacation rental furnutare      Beşiktaş   34400  41.077312
# 27271      LOVELY APT. IN PERFECT LOCATION      Cihangir   34433  41.032195
# 28277       Duplex Apartment with Terrace          Şişli   34373  41.044708
#
#        longitude  accommodates    price
# id
# 4826   29.053674             2  $562.00
# 20815  29.045452             3  $102.00
# 25436  29.038906             3  $214.00
# 27271  28.982163             2  $182.00
# 28277  28.985674             4  $605.00

# %% [markdown]
# ### Exploring the data (cont.)

# %%
print('The dataframe has {} neighbourhoods.'.format(
        len(df1['neighbourhood'].unique())
    )
)
# Out:
# The dataframe has 16 neighbourhoods.

# %%
print(df1['neighbourhood'].unique())
# Out:
# ['Üsküdar' 'Beşiktaş' 'Cihangir' 'Şişli' 'Beyoglu' 'Taksim' nan 'Karaköy'
#  'Kadıköy' 'Eminönü' 'Sultanahmet' 'Moda' 'Kadıköy Merkezi' 'Fatih'
#  'Ortaköy' 'Aksaray']

# %%
df1.shape
# Out:
# (14927, 7)

# %% [markdown]
# ### Analyzing the data
#
# Now, we explore the neighbourhoods in Istanbul city, to determine which area has the most number of properties listings.

# %%
neighbourhood_tab = pd.crosstab(index=df1["neighbourhood"], columns="count").sort_values('count', ascending=False)
neighbourhood_tab
# Out:
# col_0            count
# neighbourhood
# Şişli             2010
# Taksim            1717
# Sultanahmet       1335
# Beşiktaş          1217
# Cihangir          1107
# Karaköy            874
# Kadıköy            827
# Üsküdar            574
# Moda               503
# Fatih              452
# Kadıköy Merkezi    349
# Ortaköy            168
# Beyoglu            135
# Eminönü             56
# Aksaray             38

# %% [markdown]
# We see that "Şişli" has the greatest number of properties listings in the dataset.

# %% [markdown]
# ### Subseting the most populated neighborhood by tourists

# %%
df2 = df1[df1['neighbourhood'] == 'Şişli']

# %% [markdown]
# ### Exloring the subseted dataset

# %%
df2.shape
# Out:
# (2010, 7)

# %%
df2.head()
# Out:
#                                      name neighbourhood zipcode   latitude  \
# id
# 28277      Duplex Apartment with Terrace          Şişli   34373  41.044708
# 33368   Deluxe double bedroom @ Nisantasi         Şişli   34365  41.053821
# 87024          Nisantasi Studio Apartment         Şişli     NaN  41.050176
# 146854      Beautiful & Super Deluxe Flat         Şişli   34400  41.047530
# 175766        at the center of İstanbul..         Şişli   34387  41.070053
#
#         longitude  accommodates      price
# id
# 28277   28.985674             4    $605.00
# 33368   28.997393             2    $305.00
# 87024   28.990152             2  $1,526.00
# 146854  28.980305             1    $321.00
# 175766  28.985606             2    $161.00

# %% [markdown]
# ### Cleaning the dataset

# %% [markdown]
# We want to prepair the dataset so we can apply some analysis for its values.
#
# First let us explore the datatypes of its columns.

# %%
df2.dtypes
# Out:
# name              object
# neighbourhood     object
# zipcode           object
# latitude         float64
# longitude        float64
# accommodates       int64
# price             object
# dtype: object

# %% [markdown]
# We want to deal with the "price" column to remove the dolar sign and considet it as float values.

# %%
df2['price'].head()
# Out:
# id
# 28277       $605.00
# 33368       $305.00
# 87024     $1,526.00
# 146854      $321.00
# 175766      $161.00
# Name: price, dtype: object

# %%
df2['price'] = df2.price.str.replace("\$|,",'').astype(float)
# Out:
# C:\Users\Hazim\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# After using regular expresions to do the transformation, we notice that the column is as requested now.

# %%
df2['price'].head()
# Out:
# id
# 28277      605.0
# 33368      305.0
# 87024     1526.0
# 146854     321.0
# 175766     161.0
# Name: price, dtype: float64

# %% [markdown]
# We can also check the data type for the dataset

# %%
df2.dtypes
# Out:
# name              object
# neighbourhood     object
# zipcode           object
# latitude         float64
# longitude        float64
# accommodates       int64
# price            float64
# dtype: object

# %% [markdown]
# Since the size of the dataset is (2010, 7) as we have seen above.
#
# We will to group the data to reduce the amount of the points to be represented on the map as we are interested in the areas not properties themselves.

# %%
df3 = df2.groupby('zipcode')['zipcode', 'latitude', 'longitude', 'accommodates', 'price'].mean()

# %%
df3.shape
# Out:
# (71, 4)

# %% [markdown]
# Now we have more convenient data base to deal with, as we have 71 area zipcodes.
#
# Let us explore the data frame.

# %%
df3
# Out:
#           latitude  longitude  accommodates        price
# zipcode
# 30433    41.055030  28.979648      4.000000   252.000000
# 34000    41.063441  28.990359      2.444444   207.111111
# 340000   41.049608  28.979862      1.000000   102.000000
# 34010    41.053961  28.972479      5.000000   643.000000
# 34040    41.055292  28.997757      2.000000   305.000000
# 34100    41.065292  28.988944      2.285714   153.142857
# 34138    41.060833  28.989740      2.923077   816.230769
# 34200    41.057497  28.990658      2.388060   231.507463
# 34212    41.074091  28.999491      1.000000   134.000000
# 34240    41.060336  28.985150      2.400000   242.000000
# 34250    41.056773  28.987403      2.691489   317.744681
# 34280    41.049694  28.974294      1.000000    48.000000
# 34281    41.056324  28.983986      3.000000   182.000000
# 34295    41.047372  28.979747      1.000000    54.000000
# 34303    41.046403  28.985774      4.000000   670.000000
# 34325    41.050861  28.983203      1.500000   179.500000
# 34330    41.065143  28.992686      1.750000   336.250000
# 34331    41.063079  28.983948      2.000000   145.000000
# 34333    41.085191  29.002869      3.000000   139.000000
# 3434     41.074386  28.992794      2.000000   246.000000
# 34340    41.073413  28.983481      1.500000    64.500000
# 34342    41.075229  28.997724      4.000000    91.000000
# 34347    41.084014  29.003085      2.000000   107.000000
# 34349    41.058587  28.999777      2.800000   376.000000
# 34357    41.048746  28.996778      2.500000   807.500000
# 34360    41.058918  28.990779      2.770492   348.557377
# 34363    41.054952  28.991180      2.895349   267.872093
# 34365    41.051816  28.995695      2.820225   569.235955
# 34367    41.049650  28.989022      2.928571   363.714286
# 34370    41.050564  28.979033      2.000000   183.666667
# 34371    41.052596  28.989003      4.304348   634.565217
# 34373    41.046120  28.985468      3.653595   621.555556
# 34374    41.045595  28.977951      6.000000   241.000000
# 34375    41.048539  28.983223      2.298611   159.750000
# 34377    41.048872  28.979008      1.916667   123.791667
# 34379    41.054147  28.976882      2.545455   228.927273
# 34380    41.055290  28.983484      2.875000   271.321429
# 34381    41.060074  28.985609      3.080292   305.656934
# 34382    41.060192  28.977151      2.000000   103.400000
# 34384    41.059567  28.973036      2.166667   150.833333
# 34387    41.070543  28.993623      2.217391   212.282609
# 34389    41.053735  28.983188      2.000000   183.166667
# 34394    41.067408  29.000757      2.303191   198.579787
# 34396    41.072104  28.994640      1.000000    80.000000
# 34398    41.056333  28.998946      2.400000   361.000000
# 34400    41.060213  28.983697      2.705882   290.549020
# 34403    41.080720  28.984841      4.307692   331.692308
# 34406    41.075364  28.981473      2.000000   162.500000
# 34408    41.051245  28.989050      1.000000   241.000000
# 34410    41.079194  28.993121      1.956522   212.826087
# 34413    41.081407  29.002023      2.054545   118.400000
# 34415    41.085362  29.003361      3.130435   225.608696
# 34416    41.085930  29.004808      1.000000    86.000000
# 34427    41.046535  28.981273      2.000000   107.000000
# 34433    41.054810  28.989011      2.000000   546.000000
# 34440    41.058781  28.986206      2.000000   180.333333
# 34445    41.044722  28.978404      2.000000   182.000000
# 34453    41.060717  28.995827      6.000000   300.000000
# 34470    41.049072  28.979390      1.000000    54.000000
# 34480    41.049214  28.986067      1.000000    75.000000
# 34500    41.058319  28.991478      2.800000   381.200000
# 34510    41.055856  28.984007      5.000000  5999.000000
# 34580    41.057613  28.990124      5.000000   916.000000
# 34600    41.073357  28.999888      1.000000   129.000000
# 34829    41.056546  28.979586      2.000000   348.000000
# 34834    41.079266  28.989058      5.000000   830.000000
# 34844    41.047602  28.975537      2.000000   262.000000
# 34888    41.072384  28.995212      3.000000   161.000000
# 36360    41.053761  28.992516      3.000000  1039.000000
# 39394    41.066977  29.009212      2.000000   198.000000
# 39770    41.085114  29.004112      7.000000   343.000000

# %% [markdown]
# We notice that there are two zipcodes that has been written wrong 340000 and 3434.
#
#
# Since zipcodes in Turkey are all 5 digits. We fix them by remving a zero, and adding a zero respectively.
#
# Let us find out the data type of the 'zipcode' column.

# %%
df2['zipcode'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# Let us first replace all NA values in zipcode column by 34000, which is the main zip code for Istanbul. We also change the data type of 'zipcode' column to int32

# %%
df2['zipcode'] = df2.zipcode.fillna(34000).astype('int32')
# Out:
# C:\Users\Hazim\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# We check the 'zipcode' column data type. It is int32 now.

# %%
df2['zipcode'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# We locate the 3434 zipcode, and change it by adding 0 to its end.

# %%
df2.loc[df2['zipcode'] == 3434]
# Out:
#                                      name neighbourhood  zipcode   latitude  \
# id
# 6987797  Very central  location, sightly,         Şişli     3434  41.074386
#
#          longitude  accommodates  price
# id
# 6987797  28.992794             2  246.0

# %%
df2.loc[6987797, 'zipcode']
# Out:
# 3434

# %%
df2.loc[6987797, 'zipcode'] = 34340
# Out:
# C:\Users\Hazim\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df2.loc[6987797, 'zipcode']
# Out:
# 34340

# %% [markdown]
# We locate the 340000 zipcode, and change it by removing 0 from its end.

# %%
df2.loc[df2['zipcode'] == 340000]
# Out:
#                 name neighbourhood  zipcode   latitude  longitude  \
# id
# 9970104  Kiralık oda         Şişli   340000  41.049608  28.979862
#
#          accommodates  price
# id
# 9970104             1  102.0

# %%
df2.loc[9970104, 'zipcode']
# Out:
# 340000

# %%
df2.loc[9970104, 'zipcode'] = 34000

# %%
df2.loc[9970104, 'zipcode']
# Out:
# 34000

# %% [markdown]
# Let us explore zipcodes now.

# %%
pd.crosstab(index=df2["zipcode"], columns="count")
# Out:
# col_0    count
# zipcode
# 30433        1
# 34000      251
# 34010        1
# 34040        1
# 34100        7
# 34138       13
# 34200       67
# 34212        1
# 34240        5
# 34250       94
# 34280        1
# 34281        1
# 34295        1
# 34303        1
# 34325        2
# 34330        4
# 34331        1
# 34333        1
# 34340        3
# 34342        1
# 34347        1
# 34349        5
# 34357        4
# 34360      122
# 34363       86
# 34365       89
# 34367       14
# 34370        3
# 34371       23
# 34373      153
# 34374        1
# 34375      144
# 34377       48
# 34379       55
# 34380       56
# 34381      137
# 34382       20
# 34384        6
# 34387      138
# 34389        6
# 34394      188
# 34396        1
# 34398        5
# 34400      102
# 34403       13
# 34406        6
# 34408        1
# 34410       23
# 34413       55
# 34415       23
# 34416        1
# 34427        1
# 34433        1
# 34440        3
# 34445        1
# 34453        1
# 34470        1
# 34480        1
# 34500        5
# 34510        1
# 34580        1
# 34600        1
# 34829        1
# 34834        1
# 34844        1
# 34888        1
# 36360        1
# 39394        1
# 39770        1

# %% [markdown]
# It seems there is no problem. We can try to solve our problem now.

# %% [markdown]
# ## Exploring and analyzing the dataframe to find the best locations
#
# We group the data frame again, and explore them. We sort the grouped data descending by price.

# %%
df3 = df2.groupby('zipcode')['zipcode', 'latitude', 'longitude', 'accommodates', 'price'].mean()

# %%
df3.shape
# Out:
# (69, 5)

# %%
df4 = df3.sort_values('price', ascending=False)
df4
# Out:
#          zipcode   latitude  longitude  accommodates        price
# zipcode
# 34510      34510  41.055856  28.984007      5.000000  5999.000000
# 36360      36360  41.053761  28.992516      3.000000  1039.000000
# 34580      34580  41.057613  28.990124      5.000000   916.000000
# 34834      34834  41.079266  28.989058      5.000000   830.000000
# 34138      34138  41.060833  28.989740      2.923077   816.230769
# 34357      34357  41.048746  28.996778      2.500000   807.500000
# 34303      34303  41.046403  28.985774      4.000000   670.000000
# 34010      34010  41.053961  28.972479      5.000000   643.000000
# 34371      34371  41.052596  28.989003      4.304348   634.565217
# 34373      34373  41.046120  28.985468      3.653595   621.555556
# 34365      34365  41.051816  28.995695      2.820225   569.235955
# 34433      34433  41.054810  28.989011      2.000000   546.000000
# 34000      34000  41.060191  28.989232      2.601594   448.856574
# 34500      34500  41.058319  28.991478      2.800000   381.200000
# 34349      34349  41.058587  28.999777      2.800000   376.000000
# 34367      34367  41.049650  28.989022      2.928571   363.714286
# 34398      34398  41.056333  28.998946      2.400000   361.000000
# 34360      34360  41.058918  28.990779      2.770492   348.557377
# 34829      34829  41.056546  28.979586      2.000000   348.000000
# 39770      39770  41.085114  29.004112      7.000000   343.000000
# 34330      34330  41.065143  28.992686      1.750000   336.250000
# 34403      34403  41.080720  28.984841      4.307692   331.692308
# 34250      34250  41.056773  28.987403      2.691489   317.744681
# 34381      34381  41.060074  28.985609      3.080292   305.656934
# 34040      34040  41.055292  28.997757      2.000000   305.000000
# 34453      34453  41.060717  28.995827      6.000000   300.000000
# 34400      34400  41.060213  28.983697      2.705882   290.549020
# 34380      34380  41.055290  28.983484      2.875000   271.321429
# 34363      34363  41.054952  28.991180      2.895349   267.872093
# 34844      34844  41.047602  28.975537      2.000000   262.000000
# 30433      30433  41.055030  28.979648      4.000000   252.000000
# 34240      34240  41.060336  28.985150      2.400000   242.000000
# 34408      34408  41.051245  28.989050      1.000000   241.000000
# 34374      34374  41.045595  28.977951      6.000000   241.000000
# 34200      34200  41.057497  28.990658      2.388060   231.507463
# 34379      34379  41.054147  28.976882      2.545455   228.927273
# 34415      34415  41.085362  29.003361      3.130435   225.608696
# 34410      34410  41.079194  28.993121      1.956522   212.826087
# 34387      34387  41.070543  28.993623      2.217391   212.282609
# 34394      34394  41.067408  29.000757      2.303191   198.579787
# 39394      39394  41.066977  29.009212      2.000000   198.000000
# 34370      34370  41.050564  28.979033      2.000000   183.666667
# 34389      34389  41.053735  28.983188      2.000000   183.166667
# 34281      34281  41.056324  28.983986      3.000000   182.000000
# 34445      34445  41.044722  28.978404      2.000000   182.000000
# 34440      34440  41.058781  28.986206      2.000000   180.333333
# 34325      34325  41.050861  28.983203      1.500000   179.500000
# 34406      34406  41.075364  28.981473      2.000000   162.500000
# 34888      34888  41.072384  28.995212      3.000000   161.000000
# 34375      34375  41.048539  28.983223      2.298611   159.750000
# 34100      34100  41.065292  28.988944      2.285714   153.142857
# 34384      34384  41.059567  28.973036      2.166667   150.833333
# 34331      34331  41.063079  28.983948      2.000000   145.000000
# 34333      34333  41.085191  29.002869      3.000000   139.000000
# 34212      34212  41.074091  28.999491      1.000000   134.000000
# 34600      34600  41.073357  28.999888      1.000000   129.000000
# 34340      34340  41.073738  28.986585      1.666667   125.000000
# 34377      34377  41.048872  28.979008      1.916667   123.791667
# 34413      34413  41.081407  29.002023      2.054545   118.400000
# 34347      34347  41.084014  29.003085      2.000000   107.000000
# 34427      34427  41.046535  28.981273      2.000000   107.000000
# 34382      34382  41.060192  28.977151      2.000000   103.400000
# 34342      34342  41.075229  28.997724      4.000000    91.000000
# 34416      34416  41.085930  29.004808      1.000000    86.000000
# 34396      34396  41.072104  28.994640      1.000000    80.000000
# 34480      34480  41.049214  28.986067      1.000000    75.000000
# 34470      34470  41.049072  28.979390      1.000000    54.000000
# 34295      34295  41.047372  28.979747      1.000000    54.000000
# 34280      34280  41.049694  28.974294      1.000000    48.000000

# %% [markdown]
# It seems as there is no problem, and we can use the dataframe to subset the five most expensive zipcodes according to the price column.

# %%
max_zipcodes = df4[['zipcode']][0:5]
max_zipcodes = max_zipcodes['zipcode'].tolist()
max_zipcodes
# Out:
# [34510, 36360, 34580, 34834, 34138]

# %% [markdown]
# We find the targeted zipcodes:
# [34510, 36360, 34580, 34834, 34138]

# %% [markdown]
# ## Visualizing the data and the results

# %% [markdown]
# We use 'geopy' library in order to get the latitude and longitude values of 'Şişli, Istanbul'

# %%
address = 'Şişli, Istanbul'

geolocator = Nominatim(user_agent="coursera-capstone-project")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Şişli, Istanbul are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Şişli, Istanbul are 41.061672, 28.9842605962855.

# %% [markdown]
# Later, we create a map of Şişli, Istanbul, which is the most populated neighborhood by tourist in Istanbul, according to the data frame. We also add markers to the map in order to highlight the average targeted zipcodes in Şişli. We color the most expensive zipcodes of according to the price-per-night variable by red. The others are colored by blue.

# %%
# create map of Istanbul using latitude and longitude values
map_Istanbul = folium.Map(location=[latitude, longitude], zoom_start=13)

# add markers to map
for lat, lng, zipcode in zip(df3['latitude'], df3['longitude'], df3['zipcode']):
    label = '{}'.format(zipcode)
    label = folium.Popup(label, parse_html=True)
    if zipcode in max_zipcodes: 
        color_o = 'red' 
    else: 
        color_o = 'blue'
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=color_o,
        fill=True,
        fill_color=color_o,
        fill_opacity=0.7).add_to(map_Istanbul)  
    
map_Istanbul
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now the tourists company can start its advertisement campaign for its touristic tours in the areas marked by red.
